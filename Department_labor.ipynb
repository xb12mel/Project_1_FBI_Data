# %%
# Dependencies
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import requests
# import time
# from scipy.stats import linregress
# from matplotlib import pyplot as plt
from config import api_key

# %%
url = f"https://api.bls.gov/publicAPI/v2/timeseries/data/%20?registrationkey=4d6899fd4e3d4025b1bce92eed169055&%20catalog=true&startyear=2010&endyear=2014&calculations=true%20&annualaverage=true&aspects=true"

# %%
import requests
import json
import prettytable

headers = {'Content-type': 'application/json'}

data = json.dumps({"seriesid": ['CUUR0000SA0','LAUST510000000000003'],"startyear":"2009", "endyear":"2019"})
p = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data, headers=headers)
json_data = json.loads(p.text)

for series in json_data['Results']['series']:
    x=prettytable.PrettyTable(["series id","year","period","monthly average","footnotes"])
    seriesId = series['seriesID']
    for item in series['data']:
        year = item['year']
        period = item['period']
        value = item['value']
        footnotes=""
        for footnote in item['footnotes']:
            if footnote:
                footnotes = footnotes + footnote['text'] + ','
    #'if 'M01' <= period <= 'M12':'
            x.add_row([seriesId,year,period,value,footnotes[0:-1]])
output_va_unemployed = open(seriesId + '.txt','w')
output_va_unemployed.write (x.get_string())
output.close()

print(x)
# Out:
# +----------------------+------+--------+-----------------+-----------+
# |      series id       | year | period | monthly average | footnotes |
# +----------------------+------+--------+-----------------+-----------+
# | LAUST510000000000003 | 2018 |  M12   |       2.8       |           |
# | LAUST510000000000003 | 2018 |  M11   |       2.7       |           |
# | LAUST510000000000003 | 2018 |  M10   |       2.8       |           |
# | LAUST510000000000003 | 2018 |  M09   |       2.8       |           |
# | LAUST510000000000003 | 2018 |  M08   |       3.2       |           |
# | LAUST510000000000003 | 2018 |  M07   |       3.1       |           |
# | LAUST510000000000003 | 2018 |  M06   |       3.3       |           |
# | LAUST510000000000003 | 2018 |  M05   |       2.8       |           |
# | LAUST510000000000003 | 2018 |  M04   |       2.8       |           |
# | LAUST510000000000003 | 2018 |  M03   |       3.2       |           |
# | LAUST510000000000003 | 2018 |  M02   |       3.4       |           |
# | LAUST510000000000003 | 2018 |  M01   |       3.6       |           |
# | LAUST510000000000003 | 2017 |  M12   |       3.1       |           |
# | LAUST510000000000003 | 2017 |  M11   |       3.3       |           |
# | LAUST510000000000003 | 2017 |  M10   |       3.3       |           |
# | LAUST510000000000003 | 2017 |  M09   |       3.5       |           |
# | LAUST510000000000003 | 2017 |  M08   |       3.9       |           |
# | LAUST510000000000003 | 2017 |  M07   |       3.8       |           |
# | LAUST510000000000003 | 2017 |  M06   |       3.8       |           |
# | LAUST510000000000003 | 2017 |  M05   |       3.7       |           |
# | LAUST510000000000003 | 2017 |  M04   |       3.5       |           |
# | LAUST510000000000003 | 2017 |  M03   |       3.9       |           |
# | LAUST510000000000003 | 2017 |  M02   |       4.2       |           |
# | LAUST510000000000003 | 2017 |  M01   |       4.4       |           |
# | LAUST510000000000003 | 2016 |  M12   |       3.8       |           |
# | LAUST510000000000003 | 2016 |  M11   |       3.9       |           |
# | LAUST510000000000003 | 2016 |  M10   |       4.0       |           |
# | LAUST510000000000003 | 2016 |  M09   |       4.2       |           |
# | LAUST510000000000003 | 2016 |  M08   |       4.4       |           |
# | LAUST510000000000003 | 2016 |  M07   |       4.3       |           |
# | LAUST510000000000003 | 2016 |  M06   |       4.3       |           |
# | LAUST510000000000003 | 2016 |  M05   |       3.9       |           |
# | LAUST510000000000003 | 2016 |  M04   |       3.7       |           |
# | LAUST510000000000003 | 2016 |  M03   |       4.1       |           |
# | LAUST510000000000003 | 2016 |  M02   |       4.2       |           |
# | LAUST510000000000003 | 2016 |  M01   |       4.3       |           |
# | LAUST510000000000003 | 2015 |  M12   |       3.8       |           |
# | LAUST510000000000003 | 2015 |  M11   |       3.9       |           |
# | LAUST510000000000003 | 2015 |  M10   |       4.0       |           |
# | LAUST510000000000003 | 2015 |  M09   |       4.1       |           |
# | LAUST510000000000003 | 2015 |  M08   |       4.4       |           |
# | LAUST510000000000003 | 2015 |  M07   |       4.5       |           |
# | LAUST510000000000003 | 2015 |  M06   |       4.6       |           |
# | LAUST510000000000003 | 2015 |  M05   |       4.7       |           |
# | LAUST510000000000003 | 2015 |  M04   |       4.3       |           |
# | LAUST510000000000003 | 2015 |  M03   |       4.8       |           |
# | LAUST510000000000003 | 2015 |  M02   |       5.0       |           |
# | LAUST510000000000003 | 2015 |  M01   |       5.2       |           |
# | LAUST510000000000003 | 2014 |  M12   |       4.6       |           |
# | LAUST510000000000003 | 2014 |  M11   |       4.8       |           |
# | LAUST510000000000003 | 2014 |  M10   |       4.8       |           |
# | LAUST510000000000003 | 2014 |  M09   |       5.1       |           |
# | LAUST510000000000003 | 2014 |  M08   |       5.5       |           |
# | LAUST510000000000003 | 2014 |  M07   |       5.5       |           |
# | LAUST510000000000003 | 2014 |  M06   |       5.4       |           |
# | LAUST510000000000003 | 2014 |  M05   |       5.3       |           |
# | LAUST510000000000003 | 2014 |  M04   |       4.8       |           |
# | LAUST510000000000003 | 2014 |  M03   |       5.6       |           |
# | LAUST510000000000003 | 2014 |  M02   |       5.7       |           |
# | LAUST510000000000003 | 2014 |  M01   |       5.7       |           |
# | LAUST510000000000003 | 2013 |  M12   |       5.1       |           |
# | LAUST510000000000003 | 2013 |  M11   |       5.3       |           |
# | LAUST510000000000003 | 2013 |  M10   |       5.7       |           |
# | LAUST510000000000003 | 2013 |  M09   |       5.6       |           |
# | LAUST510000000000003 | 2013 |  M08   |       5.8       |           |
# | LAUST510000000000003 | 2013 |  M07   |       5.9       |           |
# | LAUST510000000000003 | 2013 |  M06   |       6.0       |           |
# | LAUST510000000000003 | 2013 |  M05   |       5.7       |           |
# | LAUST510000000000003 | 2013 |  M04   |       5.3       |           |
# | LAUST510000000000003 | 2013 |  M03   |       5.7       |           |
# | LAUST510000000000003 | 2013 |  M02   |       6.1       |           |
# | LAUST510000000000003 | 2013 |  M01   |       6.4       |           |
# | LAUST510000000000003 | 2012 |  M12   |       5.6       |           |
# | LAUST510000000000003 | 2012 |  M11   |       5.4       |           |
# | LAUST510000000000003 | 2012 |  M10   |       5.6       |           |
# | LAUST510000000000003 | 2012 |  M09   |       5.8       |           |
# | LAUST510000000000003 | 2012 |  M08   |       6.2       |           |
# | LAUST510000000000003 | 2012 |  M07   |       6.4       |           |
# | LAUST510000000000003 | 2012 |  M06   |       6.4       |           |
# | LAUST510000000000003 | 2012 |  M05   |       6.0       |           |
# | LAUST510000000000003 | 2012 |  M04   |       5.6       |           |
# | LAUST510000000000003 | 2012 |  M03   |       6.2       |           |
# | LAUST510000000000003 | 2012 |  M02   |       6.6       |           |
# | LAUST510000000000003 | 2012 |  M01   |       6.6       |           |
# | LAUST510000000000003 | 2011 |  M12   |       6.2       |           |
# | LAUST510000000000003 | 2011 |  M11   |       6.1       |           |
# | LAUST510000000000003 | 2011 |  M10   |       6.4       |           |
# | LAUST510000000000003 | 2011 |  M09   |       6.7       |           |
# | LAUST510000000000003 | 2011 |  M08   |       6.9       |           |
# | LAUST510000000000003 | 2011 |  M07   |       6.7       |           |
# | LAUST510000000000003 | 2011 |  M06   |       6.9       |           |
# | LAUST510000000000003 | 2011 |  M05   |       6.4       |           |
# | LAUST510000000000003 | 2011 |  M04   |       6.2       |           |
# | LAUST510000000000003 | 2011 |  M03   |       6.6       |           |
# | LAUST510000000000003 | 2011 |  M02   |       6.9       |           |
# | LAUST510000000000003 | 2011 |  M01   |       7.1       |           |
# | LAUST510000000000003 | 2010 |  M12   |       6.7       |           |
# | LAUST510000000000003 | 2010 |  M11   |       6.7       |           |
# | LAUST510000000000003 | 2010 |  M10   |       6.6       |           |
# | LAUST510000000000003 | 2010 |  M09   |       6.8       |           |
# | LAUST510000000000003 | 2010 |  M08   |       7.1       |           |
# | LAUST510000000000003 | 2010 |  M07   |       7.1       |           |
# | LAUST510000000000003 | 2010 |  M06   |       7.2       |           |
# | LAUST510000000000003 | 2010 |  M05   |       7.1       |           |
# | LAUST510000000000003 | 2010 |  M04   |       7.0       |           |
# | LAUST510000000000003 | 2010 |  M03   |       7.7       |           |
# | LAUST510000000000003 | 2010 |  M02   |       7.9       |           |
# | LAUST510000000000003 | 2010 |  M01   |       7.9       |           |
# | LAUST510000000000003 | 2009 |  M12   |       7.2       |           |
# | LAUST510000000000003 | 2009 |  M11   |       6.8       |           |
# | LAUST510000000000003 | 2009 |  M10   |       6.8       |           |
# | LAUST510000000000003 | 2009 |  M09   |       6.9       |           |
# | LAUST510000000000003 | 2009 |  M08   |       6.9       |           |
# | LAUST510000000000003 | 2009 |  M07   |       6.8       |           |
# | LAUST510000000000003 | 2009 |  M06   |       7.0       |           |
# | LAUST510000000000003 | 2009 |  M05   |       6.7       |           |
# | LAUST510000000000003 | 2009 |  M04   |       6.2       |           |
# | LAUST510000000000003 | 2009 |  M03   |       6.6       |           |
# | LAUST510000000000003 | 2009 |  M02   |       6.4       |           |
# | LAUST510000000000003 | 2009 |  M01   |       6.1       |           |
# +----------------------+------+--------+-----------------+-----------+

# %%
import pandas as pd

# %%
va_unemployement = "../Project_1_FBI_Data/va_unemployement.csv"
va_unemployement_df = pd.read_csv(va_unemployement)
va_unemployement_df.head(25)
# Out:
#           series id          year    period    monthly average    footnotes
# 0                      NaN     NaN       NaN                NaN          NaN
# 1    LAUST510000000000003   2018.0    M12                   2.8
# 2    LAUST510000000000003   2018.0    M11                   2.7
# 3    LAUST510000000000003   2018.0    M10                   2.8
# 4    LAUST510000000000003   2018.0    M09                   2.8
# 5    LAUST510000000000003   2018.0    M08                   3.2
# 6    LAUST510000000000003   2018.0    M07                   3.1
# 7    LAUST510000000000003   2018.0    M06                   3.3
# 8    LAUST510000000000003   2018.0    M05                   2.8
# 9    LAUST510000000000003   2018.0    M04                   2.8
# 10   LAUST510000000000003   2018.0    M03                   3.2
# 11   LAUST510000000000003   2018.0    M02                   3.4
# 12   LAUST510000000000003   2018.0    M01                   3.6
# 13   LAUST510000000000003   2017.0    M12                   3.1
# 14   LAUST510000000000003   2017.0    M11                   3.3
# 15   LAUST510000000000003   2017.0    M10                   3.3
# 16   LAUST510000000000003   2017.0    M09                   3.5
# 17   LAUST510000000000003   2017.0    M08                   3.9
# 18   LAUST510000000000003   2017.0    M07                   3.8
# 19   LAUST510000000000003   2017.0    M06                   3.8
# 20   LAUST510000000000003   2017.0    M05                   3.7
# 21   LAUST510000000000003   2017.0    M04                   3.5
# 22   LAUST510000000000003   2017.0    M03                   3.9
# 23   LAUST510000000000003   2017.0    M02                   4.2
# 24   LAUST510000000000003   2017.0    M01                   4.4

# %%
va_unemployement_df.to_csv("unemployement_df.csv", index=False, header=True)

# %%
clean_unemployement= "../Project_1_FBI_Data/unemployement_df.csv"
clean_unemployement_df = pd.read_csv(clean_unemployement)
clean_unemployement_df.head(25)
# Out:
#                 series id    year period  monthly average
# 0    LAUST510000000000003  2018.0    M12              2.8
# 1    LAUST510000000000003  2018.0    M11              2.7
# 2    LAUST510000000000003  2018.0    M10              2.8
# 3    LAUST510000000000003  2018.0    M09              2.8
# 4    LAUST510000000000003  2018.0    M08              3.2
# 5    LAUST510000000000003  2018.0    M07              3.1
# 6    LAUST510000000000003  2018.0    M06              3.3
# 7    LAUST510000000000003  2018.0    M05              2.8
# 8    LAUST510000000000003  2018.0    M04              2.8
# 9    LAUST510000000000003  2018.0    M03              3.2
# 10   LAUST510000000000003  2018.0    M02              3.4
# 11   LAUST510000000000003  2018.0    M01              3.6
# 12   LAUST510000000000003  2017.0    M12              3.1
# 13   LAUST510000000000003  2017.0    M11              3.3
# 14   LAUST510000000000003  2017.0    M10              3.3
# 15   LAUST510000000000003  2017.0    M09              3.5
# 16   LAUST510000000000003  2017.0    M08              3.9
# 17   LAUST510000000000003  2017.0    M07              3.8
# 18   LAUST510000000000003  2017.0    M06              3.8
# 19   LAUST510000000000003  2017.0    M05              3.7
# 20   LAUST510000000000003  2017.0    M04              3.5
# 21   LAUST510000000000003  2017.0    M03              3.9
# 22   LAUST510000000000003  2017.0    M02              4.2
# 23   LAUST510000000000003  2017.0    M01              4.4
# 24   LAUST510000000000003  2016.0    M12              3.8

# %%
# find out what's keeping us from adjusting the columns
clean_unemployement_df.columns
# Out:
# Index([' series id', ' year', 'period', 'monthly average'], dtype='object')

# %%
# remove the series id from the dataframe
clean_va_unemployement_df = clean_unemployement_df[[" year", "period", "monthly average"]]

# %%
average_unemployement = clean_unemployement_df.groupby([" year"]).mean()
# monthly_avg = plt.plot(period, monthly average, color="blue", label="Monthly Average")
# plt
average_unemployement
# Out:
#         monthly average
#  year
# 2009.0         6.700000
# 2010.0         7.150000
# 2011.0         6.591667
# 2012.0         6.033333
# 2013.0         5.716667
# 2014.0         5.233333
# 2015.0         4.441667
# 2016.0         4.091667
# 2017.0         3.700000
# 2018.0         3.041667

# %%
va_avg_unemployment = average_unemployement.plot.line()
plt.legend(handles=["monthly average"], loc="best")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-1c24d24ff171> in <module>
#       1 va_avg_unemployment = average_unemployement.plot.line()
# ----> 2 plt.legend(handles=["monthly average"], loc="best")
#
# NameError: name 'plt' is not defined
